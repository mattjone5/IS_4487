# %% [markdown]
# <a href="https://colab.research.google.com/github/mattjones5/IS_4487/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/megatelco.csv')

print (df)

# %%
#look at the top rows
df.head(10)

# %%
#look at last rows
df.tail(10)

# %%
#get a summary of the dataset
df.describe()

# %%
#look at the datatypes
df.info()

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?

# %%
df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000)]
df_clean.describe()

# %% [markdown]
# # Add Derived Attribute
#
# Add a column with the income in K (thousands)

# %%
df_clean['income_k'] = (df_clean['income']/1000).round(2)
df_clean.head()

# %% [markdown]
# ## Slice the data
#  What is average house price at the two levels of leave?
#
#  Conclusion?  Stayers have substantially more expensive homes.

# %%
df_clean[['house','leave']].groupby('leave').mean().round(2)

# %% [markdown]
# # LAB 3 CODE BELOW!!!

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/retail_dataset.csv')

print (df)
# Out:
# Mounted at /content/gdrive
#       customer_id      customer_name          address_line_1          city  \
# 0              67      Gordy Matteau     59 Northland Circle    Wilmington
# 1             201     Cort Paskerful         769 Buell Drive    Huntsville
# 2              45    Willetta Lumley       41 Ridgeway Alley        Irvine
# 3             106   Alison Batterton           489 Erie Hill      Richmond
# 4             357  Martelle Paxeford    451 Manitowish Place      Richmond
# ...           ...                ...                     ...           ...
# 9564          637  Jayson Andriessen  0819 Crownhardt Circle     Allentown
# 9565          370    Darby Tesseyman     7468 Jackson Circle        Albany
# 9566          598   Henka De Ferrari      89 Sunnyside Drive  Redwood City
# 9567          737    Tommie Penvarne    9630 Washington Hill     Watertown
# 9568          482       Matelda Bull      6406 Bultman Alley  Gaithersburg
#
# ...

# %%
#df["total_amount"] = pd.to_numeric(df["total_amount"].str.replace("$",""))
df["total_amount"] = df["total_amount"].str.replace("$","")
df["total_amount"] = pd.to_numeric(df["total_amount"].str.replace(",",""))
df["total_amount"] = pd.to_numeric(df["total_amount"]).astype(float)
df
# Out:
# <ipython-input-115-b99f3b3ae453>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["total_amount"] = df["total_amount"].str.replace("$","")
#       customer_id      customer_name          address_line_1          city  \
# 0              67      Gordy Matteau     59 Northland Circle    Wilmington
# 1             201     Cort Paskerful         769 Buell Drive    Huntsville
# 2              45    Willetta Lumley       41 Ridgeway Alley        Irvine
# 3             106   Alison Batterton           489 Erie Hill      Richmond
# 4             357  Martelle Paxeford    451 Manitowish Place      Richmond
# ...           ...                ...                     ...           ...
# 9564          637  Jayson Andriessen  0819 Crownhardt Circle     Allentown
# 9565          370    Darby Tesseyman     7468 Jackson Circle        Albany
# ...

# %%
df1.dropna()
# Out:
#       customer_id      customer_name        address_line_1          city  \
# 0              67      Gordy Matteau   59 Northland Circle    Wilmington
# 1             201     Cort Paskerful       769 Buell Drive    Huntsville
# 2              45    Willetta Lumley     41 Ridgeway Alley        Irvine
# 3             106   Alison Batterton         489 Erie Hill      Richmond
# 4             357  Martelle Paxeford  451 Manitowish Place      Richmond
# ...           ...                ...                   ...           ...
# 9561          240     Barnard Hatley        5541 Kim Alley        Duluth
# 9565          370    Darby Tesseyman   7468 Jackson Circle        Albany
# 9566          598   Henka De Ferrari    89 Sunnyside Drive  Redwood City
# 9567          737    Tommie Penvarne  9630 Washington Hill     Watertown
# 9568          482       Matelda Bull    6406 Bultman Alley  Gaithersburg
#
#                  state_province  postal_code  order_id  order_date  \
# ...

# %%
df1.describe()
# Out:
#        customer_id   postal_code     order_id  customer_id.1   order_id.1  \
# count  8981.000000   8981.000000  8981.000000    8981.000000  8981.000000
# mean    268.464982  52230.965371  4974.766173     268.464982  4974.766173
# std     189.860282  29663.530626  2034.447409     189.860282  2034.447409
# min       1.000000   1105.000000  1001.000000       1.000000  1001.000000
# 25%     121.000000  27404.000000  3246.000000     121.000000  3246.000000
# 50%     243.000000  48295.000000  5430.000000     243.000000  5430.000000
# 75%     362.000000  79923.000000  6675.000000     362.000000  6675.000000
# max     800.000000  99812.000000  8147.000000     800.000000  8147.000000
#
#         product_id     quantity  product_id.1  total_amount
# count  8981.000000  8981.000000   8981.000000   8981.000000
# mean    106.688231     3.344394    106.688231    344.002359
# std       3.657543     4.244108      3.657543    375.985611
# min     101.000000     1.000000    101.000000      1.990000
# ...

# %%
df1G = df1.groupby("order_month")
df1G.first()
# Out:
#              customer_id      customer_name        address_line_1  \
# order_month
# April                178     Mycah McMaster        6 Troy Parkway
# August               161    Kendricks Bernt     43 Red Cloud Road
# December             106   Alison Batterton         489 Erie Hill
# February             351      Glenn Reville    3 Springview Drive
# January               67      Gordy Matteau   59 Northland Circle
# July                 383    Corinne Rysdale     771 Porter Circle
# June                 357  Martelle Paxeford  451 Manitowish Place
# March                393       Ozzy Yockley         01 Algoma Way
# May                   83       Saxe Southam      6 Pankratz Drive
# November             201     Cort Paskerful       769 Buell Drive
# October              233  Cosette Berkowitz       7619 Susan Lane
# September             45    Willetta Lumley     41 Ridgeway Alley
#
#                     city             state_province  postal_code  order_id  \
# order_month
# ...
