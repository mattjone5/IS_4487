# %% [markdown]
# <a href="https://colab.research.google.com/github/mattjones5/IS_4487/blob/main/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/Twitter_dataset.csv', encoding="latin1")

print (df)
# Out:
# Mounted at /content/gdrive
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
# ...

# %%
df
# Out:
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
#                 id               id_str  \
# ...

# %%
mAndMOnly = df.loc[df['text'].str.contains("M&amp;M", case=False)]
#mAndMOnly.tail(10)
mAndMOnly['text'] = mAndMOnly['text'].str.replace('?',"")
mAndMOnly
# Out:
# <ipython-input-34-3ce740b70c9c>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mAndMOnly['text'] = mAndMOnly['text'].str.replace('?',"")
# <ipython-input-34-3ce740b70c9c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mAndMOnly['text'] = mAndMOnly['text'].str.replace('?',"")
#       Unnamed: 0                       _id                      created_at  \
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# ...

# %%
isNotRetweet = mAndMOnly['retweeted_status'].isna().sum()

dfNew = pd.DataFrame([isNotRetweet, isRetweeted], index=['IsNotRetweeted', 'IsRetweeted'], columns=['x'])
dfNew.plot(kind='pie', subplots=True, figsize=(8, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6e320e5d3043> in <module>
#       1 isNotRetweet = mAndMOnly['retweeted_status'].isna().sum()
#       2
# ----> 3 dfNew = pd.DataFrame([isNotRetweet, isRetweeted], index=['IsNotRetweeted', 'IsRetweeted'], columns=['x'])
#       4 dfNew.plot(kind='pie', subplots=True, figsize=(8, 8))
#       5 plt.show()
#
# NameError: name 'isRetweeted' is not defined
